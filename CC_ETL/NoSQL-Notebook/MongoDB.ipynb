# %%
from IPython.core.display import HTML
def css_styling():   
    styles = open("styles/custom.css", "r").read() 
    return HTML(styles)

# %% [markdown]
# # 1 Introduction to MongoDB
# <small>This introduction is partially inspired on the notes of Alberto Negron's [blog](http://altons.github.io/python/2013/01/21/gentle-introduction-to-mongodb-using-pymongo/)</small>

# %% [markdown]
# MongoDB is a document-oriented database, part of the NoSQL family of database systems. MongoDB stores structured data as JSON-like structures. From a pythonic point of view it is like storing dictionary data structures. One of its main feature is its schema-less feature, i.e. it supports dynamic schemas. A schema in a relational database informally referst to the structure of the data it stores, i.e. what kind of data, which tables, which relations, etc.

# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in mlab.com
# + Build a free instance of 0,5Gb
# + Create a Database named cloudcomputing and an User, and connect to it

# %%
# !pip install pymongo
# !pip install dnspython

# %%
ls

# %%
#指定dbname
import pymongo

try:
    #use your database name, user and password here:
    #mongodb://<dbuser>:<dbpassword>@<mlab_url>/<database_name>
    with open("credentials.txt", 'r', encoding='utf-8') as f:
        [name,password,url,dbname]=f.read().splitlines()
    client=pymongo.MongoClient("mongodb://{}:{}@{}/{}".format(name,password,url,dbname))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
client
# Out:
# Connected successfully!!!
# MongoClient(host=['cluster0-shard-00-01-ijaek.mongodb.net:27017', 'cluster0-shard-00-00-ijaek.mongodb.net:27017', 'cluster0-shard-00-02-ijaek.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority/cloudcomputing')

# %%
from pymongo.errors import ConnectionFailure
url = 'mongodb://leroy19:asdf123456789@cluster0-shard-00-00-ijaek.mongodb.net:27017' 
client=pymongo.MongoClient(url+"/?ssl=true&ssl_cert_reqs=CERT_NONE")
# try:
#     # The ismaster command is cheap and does not require auth.
#     client.admin.command('ismaster')
# except ConnectionFailure:
#     print("Server not available")

client
# Out:
# MongoClient(host=['cluster0-shard-00-00-ijaek.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, ssl_cert_reqs=<VerifyMode.CERT_NONE: 0>)

# %%
#用local的pymongo
import pymongo
client = pymongo.MongoClient(host='localhost', port=27017)

db = client['test']

# %%
db = client['cloudcomputing']

# %%
collection = db.edu
collection
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00-ijaek.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, ssl_cert_reqs=<VerifyMode.CERT_NONE: 0>), 'cloudcomputing'), 'edu')

# %%
collection.insert_many(df.to_dict("records"))

# %%
import pymongo

try:
    #use your database name, user and password here:
    #mongodb://<dbuser>:<dbpassword>@<mlab_url>/<database_name>
    with open("credentials.txt", 'r', encoding='utf-8') as f:
        [name,password,url]=f.read().splitlines()
    connCC=pymongo.MongoClient("mongodb://{}:{}@{}".format("tony13game","tony5974","cluster0-ijaek.mongodb.net/test?retryWrites=true&w=majority"))
    connCC
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
#connCC
# Out:
# Connected successfully!!!

# %% [markdown]
# We can **access** to the remote database using attribute access  `db = conn.name_db` or dictionary acces `db = conn[name_db]``

# %%
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
dbCC = connCC['cloudcomputing']
print (dbCC)
# Out:
# Database(MongoClient(host=['cluster0-ijaek.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority'), 'cloudcomputing')

# %% [markdown]
# A database stores a **collection**. A collection is a group of documents stored in MongoDB, and can be thought of as the equivalent of a table in a relational database. Getting a collection in PyMongo works the same as getting a database:

# %%
#new collection
collection = dbCC.edu
collection
# Out:
# Collection(Database(MongoClient(host=['cluster0-ijaek.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority'), 'cloudcomputing'), 'edu')

# %% [markdown]
# MongoDB stores structured data as JSON-like documents, using dynamic schemas (called BSON), rather than predefined schemas. An element of data is called a document, and documents are stored in collections. One collection may have any number of documents.
#
# Compared to relational databases, we could say collections are like tables, and documents are like records. But there is one big difference: every record in a table has the same fields (with, usually, differing values) in the same order, while each document in a collection can have completely different fields from the other documents.
#
# All you really need to know when you're using Python, however, is that documents are Python dictionaries that can have strings as keys and can contain various primitive types (int, float,unicode, datetime) as well as other documents (Python dicts) and arrays (Python lists).
#
# To insert some data into MongoDB, all we need to do is create a dict and call .insert() on the collection object. Let us exemplify this process by getting some DatFrame and storing it in the collection.

# %%
import pandas as pd
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
df.head(10)
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
# 5  2005  European Union (28 countries)
# 6  2006  European Union (28 countries)
# 7  2007  European Union (28 countries)
# 8  2008  European Union (28 countries)
# 9  2009  European Union (28 countries)
#
#                                             INDIC_ED  Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...    NaN                NaN
# 1  Total public expenditure on education as % of ...    NaN                NaN
# 2  Total public expenditure on education as % of ...   5.00                  e
# 3  Total public expenditure on education as % of ...   5.03                  e
# 4  Total public expenditure on education as % of ...   4.95                  e
# 5  Total public expenditure on education as % of ...   4.92                  e
# 6  Total public expenditure on education as % of ...   4.91                  e
# 7  Total public expenditure on education as % of ...   4.92                  e
# 8  Total public expenditure on education as % of ...   5.04                  e
# 9  Total public expenditure on education as % of ...   5.38                  e

# %%
dict1=df.to_dict("records") #json:

# %%
df.to_dict("records") #json:
# Out:
# [{'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.52,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.37,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.77,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.45,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.13,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.71,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.63,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Lithuania',
# ...
#  {'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.35,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2001,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.39,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.21,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 2.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2007,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.76,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.99,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.31,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.19,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.85,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.8,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.61,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.89,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.3,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.18,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
dict1[0]

# %%
collection.insert_one({'TIME': 2000,
 'GEO': 'European Union (28 countries)',
 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined'})

# %%
for a in dict1:
    collection.insert_one(a)

# %%
#insert documents in the collection
collection.insert_many(df.to_dict("records"))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-44-371e4bc8b18e> in <module>
#       1 #insert documents in the collection
# ----> 2 collection.insert_many(df.to_dict("records"))
#
# //anaconda3/lib/python3.7/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
#     757         blk.ops = [doc for doc in gen()]
# --> 758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     760
#
# //anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     509                 self.execute_no_results(sock_info, generator)
#     510         else:
# --> 511             return self.execute_command(generator, write_concern, session)
#     512
#     513
#
# //anaconda3/lib/python3.7/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     342
#     343         client = self.collection.database.client
# --> 344         with client._tmp_session(session) as s:
#     345             client._retry_with_session(
#     346                 self.is_retryable, retryable_bulk, s, self)
#
# //anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# //anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1818             return
#    1819
# -> 1820         s = self._ensure_session(session)
#    1821         if s and close:
#    1822             with s:
#
# //anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1805             # Don't make implicit sessions causally consistent. Applications
#    1806             # should always opt-in.
# -> 1807             return self.__start_session(True, causal_consistency=False)
#    1808         except (ConfigurationError, InvalidOperation):
#    1809             # Sessions not supported, or multiple users authenticated.
#
# //anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1758
#    1759         # Raises ConfigurationError if sessions are not supported.
# -> 1760         server_session = self._get_server_session()
#    1761         opts = client_session.SessionOptions(**kwargs)
#    1762         return client_session.ClientSession(
#
# //anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1791     def _get_server_session(self):
#    1792         """Internal: start or resume a _ServerSession."""
# -> 1793         return self._topology.get_server_session()
#    1794
#    1795     def _return_server_session(self, server_session, lock):
#
# //anaconda3/lib/python3.7/site-packages/pymongo/topology.py in get_server_session(self)
#     475                             any_server_selector,
#     476                             self._settings.server_selection_timeout,
# --> 477                             None)
#     478                 elif not self._description.readable_servers:
#     479                     self._select_servers_loop(
#
# //anaconda3/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     203             if timeout == 0 or now > end_time:
#     204                 raise ServerSelectionTimeoutError(
# --> 205                     self._error_message(selector))
#     206
#     207             self._ensure_opened()
#
# ServerSelectionTimeoutError: cluster0-ijaek.mongodb.net:27017: [Errno 8] nodename nor servname provided, or not known

# %%
cursor = client.list_databases()
for db in cursor:
    print(db)
# Out:
# {'name': 'TripAdvisor', 'sizeOnDisk': 32768.0, 'empty': False}
# {'name': 'cloudcomputing', 'sizeOnDisk': 122880.0, 'empty': False}
# {'name': 'sample_airbnb', 'sizeOnDisk': 57483264.0, 'empty': False}
# {'name': 'sample_geospatial', 'sizeOnDisk': 1384448.0, 'empty': False}
# {'name': 'sample_mflix', 'sizeOnDisk': 45101056.0, 'empty': False}
# {'name': 'sample_supplies', 'sizeOnDisk': 1339392.0, 'empty': False}
# {'name': 'sample_training', 'sizeOnDisk': 73121792.0, 'empty': False}
# {'name': 'sample_weatherdata', 'sizeOnDisk': 4440064.0, 'empty': False}
# {'name': 'test', 'sizeOnDisk': 40960.0, 'empty': False}
# {'name': 'tony13game', 'sizeOnDisk': 8192.0, 'empty': False}
# {'name': 'admin', 'sizeOnDisk': 217088.0, 'empty': False}
# {'name': 'local', 'sizeOnDisk': 6519820288.0, 'empty': False}

# %%
# !sudo service mongod start

# %% [markdown]
# Check that we have a non empty collection.
#
# https://mlab.com/databases/cloudcomputing#collections

# %% [markdown]
# To recap, we have databases containing collections. A collection is made up of documents. Each document is made up of fields.

# %% [markdown]
# ### Retrieving data

# %%
collection.find_one() #Returns first document in the collection
# Out:
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1a8'),
#  'TIME': 2000,
#  'GEO': 'European Union (28 countries)',
#  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#  'Value': nan,
#  'Flag and Footnotes': nan}

# %% [markdown]
# To get more than a single document as the result of a query we use the find() method. find() returns a Cursor instance, which allows us to iterate over all matching documents.

# %%
collection.find()

# %%
for d in collection.find():
    print (d)
# Out:
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1a8'), 'TIME': 2000, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1a9'), 'TIME': 2001, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1aa'), 'TIME': 2002, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.0, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ab'), 'TIME': 2003, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.03, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ac'), 'TIME': 2004, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.95, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ad'), 'TIME': 2005, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.92, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ae'), 'TIME': 2006, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.91, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1af'), 'TIME': 2007, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.92, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b0'), 'TIME': 2008, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.04, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b1'), 'TIME': 2009, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.38, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b2'), 'TIME': 2010, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.41, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b3'), 'TIME': 2011, 'GEO': 'European Union (28 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.25, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b4'), 'TIME': 2000, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.91, 'Flag and Footnotes': 's'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b5'), 'TIME': 2001, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.99, 'Flag and Footnotes': 's'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b6'), 'TIME': 2002, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.0, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b7'), 'TIME': 2003, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.04, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b8'), 'TIME': 2004, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.95, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1b9'), 'TIME': 2005, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.92, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ba'), 'TIME': 2006, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.91, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1bb'), 'TIME': 2007, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.93, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1bc'), 'TIME': 2008, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.04, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1bd'), 'TIME': 2009, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.38, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1be'), 'TIME': 2010, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.41, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1bf'), 'TIME': 2011, 'GEO': 'European Union (27 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.25, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c0'), 'TIME': 2000, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.94, 'Flag and Footnotes': 's'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c1'), 'TIME': 2001, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.02, 'Flag and Footnotes': 's'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c2'), 'TIME': 2002, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.03, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c3'), 'TIME': 2003, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.06, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c4'), 'TIME': 2004, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.98, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c5'), 'TIME': 2005, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.95, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c6'), 'TIME': 2006, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.93, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c7'), 'TIME': 2007, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.95, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c8'), 'TIME': 2008, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.06, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1c9'), 'TIME': 2009, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.41, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ca'), 'TIME': 2010, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.46, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1cb'), 'TIME': 2011, 'GEO': 'European Union (25 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.31, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1cc'), 'TIME': 2000, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1cd'), 'TIME': 2001, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ce'), 'TIME': 2002, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.87, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1cf'), 'TIME': 2003, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.89, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d0'), 'TIME': 2004, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.8, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d1'), 'TIME': 2005, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.72, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d2'), 'TIME': 2006, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.69, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d3'), 'TIME': 2007, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.79, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d4'), 'TIME': 2008, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.94, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d5'), 'TIME': 2009, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.31, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d6'), 'TIME': 2010, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.28, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d7'), 'TIME': 2011, 'GEO': 'Euro area (18 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.15, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d8'), 'TIME': 2000, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1d9'), 'TIME': 2001, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1da'), 'TIME': 2002, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.86, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1db'), 'TIME': 2003, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.89, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1dc'), 'TIME': 2004, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.8, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1dd'), 'TIME': 2005, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.72, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1de'), 'TIME': 2006, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.69, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1df'), 'TIME': 2007, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.79, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e0'), 'TIME': 2008, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.94, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e1'), 'TIME': 2009, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.31, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e2'), 'TIME': 2010, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.28, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e3'), 'TIME': 2011, 'GEO': 'Euro area (17 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.15, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e4'), 'TIME': 2000, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': 'u'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e5'), 'TIME': 2001, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.98, 'Flag and Footnotes': 's'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e6'), 'TIME': 2002, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.01, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e7'), 'TIME': 2003, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.04, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e8'), 'TIME': 2004, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.96, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1e9'), 'TIME': 2005, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.89, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ea'), 'TIME': 2006, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.87, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1eb'), 'TIME': 2007, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.81, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ec'), 'TIME': 2008, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.95, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ed'), 'TIME': 2009, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.32, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ee'), 'TIME': 2010, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.29, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ef'), 'TIME': 2011, 'GEO': 'Euro area (15 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.16, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f0'), 'TIME': 2000, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': 'u'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f1'), 'TIME': 2001, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.97, 'Flag and Footnotes': 's'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f2'), 'TIME': 2002, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.0, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f3'), 'TIME': 2003, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.04, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f4'), 'TIME': 2004, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.95, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f5'), 'TIME': 2005, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.89, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f6'), 'TIME': 2006, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.87, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f7'), 'TIME': 2007, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.8, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f8'), 'TIME': 2008, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.94, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1f9'), 'TIME': 2009, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.32, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1fa'), 'TIME': 2010, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.28, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1fb'), 'TIME': 2011, 'GEO': 'Euro area (13 countries)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.15, 'Flag and Footnotes': 'e'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1fc'), 'TIME': 2000, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': 'u'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1fd'), 'TIME': 2001, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.99, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1fe'), 'TIME': 2002, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.09, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad1ff'), 'TIME': 2003, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.02, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad200'), 'TIME': 2004, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.95, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad201'), 'TIME': 2005, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.92, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad202'), 'TIME': 2006, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.98, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad203'), 'TIME': 2007, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.0, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad204'), 'TIME': 2008, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.43, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad205'), 'TIME': 2009, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.57, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad206'), 'TIME': 2010, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.58, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad207'), 'TIME': 2011, 'GEO': 'Belgium', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.55, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad208'), 'TIME': 2000, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.88, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad209'), 'TIME': 2001, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.7, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad20a'), 'TIME': 2002, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.94, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad20b'), 'TIME': 2003, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.09, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad20c'), 'TIME': 2004, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.4, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad20d'), 'TIME': 2005, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.25, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad20e'), 'TIME': 2006, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.04, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad20f'), 'TIME': 2007, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.88, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad210'), 'TIME': 2008, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.44, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad211'), 'TIME': 2009, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.58, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad212'), 'TIME': 2010, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.1, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad213'), 'TIME': 2011, 'GEO': 'Bulgaria', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.82, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad214'), 'TIME': 2000, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.83, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad215'), 'TIME': 2001, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.93, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad216'), 'TIME': 2002, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.15, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad217'), 'TIME': 2003, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.32, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad218'), 'TIME': 2004, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.2, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad219'), 'TIME': 2005, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.08, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad21a'), 'TIME': 2006, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.42, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad21b'), 'TIME': 2007, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.05, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad21c'), 'TIME': 2008, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.92, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad21d'), 'TIME': 2009, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.36, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad21e'), 'TIME': 2010, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.25, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad21f'), 'TIME': 2011, 'GEO': 'Czech Republic', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.51, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad220'), 'TIME': 2000, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.28, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad221'), 'TIME': 2001, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.44, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad222'), 'TIME': 2002, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.44, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad223'), 'TIME': 2003, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.33, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad224'), 'TIME': 2004, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.43, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad225'), 'TIME': 2005, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.3, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad226'), 'TIME': 2006, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 7.97, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad227'), 'TIME': 2007, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 7.81, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad228'), 'TIME': 2008, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 7.68, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad229'), 'TIME': 2009, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.74, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad22a'), 'TIME': 2010, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.81, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad22b'), 'TIME': 2011, 'GEO': 'Denmark', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 8.75, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad22c'), 'TIME': 2000, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.45, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad22d'), 'TIME': 2001, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.51, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad22e'), 'TIME': 2002, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.72, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad22f'), 'TIME': 2003, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.74, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad230'), 'TIME': 2004, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.62, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad231'), 'TIME': 2005, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.57, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad232'), 'TIME': 2006, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.43, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad233'), 'TIME': 2007, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.49, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad234'), 'TIME': 2008, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.57, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad235'), 'TIME': 2009, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.06, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad236'), 'TIME': 2010, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.08, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad237'), 'TIME': 2011, 'GEO': 'Germany (until 1990 former territory of the FRG)', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.98, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad238'), 'TIME': 2000, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.57, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad239'), 'TIME': 2001, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.24, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad23a'), 'TIME': 2002, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.47, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad23b'), 'TIME': 2003, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.29, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad23c'), 'TIME': 2004, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.92, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad23d'), 'TIME': 2005, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.88, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad23e'), 'TIME': 2006, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.7, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad23f'), 'TIME': 2007, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.72, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad240'), 'TIME': 2008, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.61, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad241'), 'TIME': 2009, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.03, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad242'), 'TIME': 2010, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.66, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad243'), 'TIME': 2011, 'GEO': 'Estonia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.16, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad244'), 'TIME': 2000, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.29, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad245'), 'TIME': 2001, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.24, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad246'), 'TIME': 2002, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.27, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad247'), 'TIME': 2003, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.35, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad248'), 'TIME': 2004, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.66, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad249'), 'TIME': 2005, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.72, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad24a'), 'TIME': 2006, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.73, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad24b'), 'TIME': 2007, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.92, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad24c'), 'TIME': 2008, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.67, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad24d'), 'TIME': 2009, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.43, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad24e'), 'TIME': 2010, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.41, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad24f'), 'TIME': 2011, 'GEO': 'Ireland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.15, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad250'), 'TIME': 2000, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.71, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad251'), 'TIME': 2001, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.5, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad252'), 'TIME': 2002, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.57, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad253'), 'TIME': 2003, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.56, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad254'), 'TIME': 2004, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.83, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad255'), 'TIME': 2005, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.09, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad256'), 'TIME': 2006, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad257'), 'TIME': 2007, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad258'), 'TIME': 2008, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad259'), 'TIME': 2009, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad25a'), 'TIME': 2010, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad25b'), 'TIME': 2011, 'GEO': 'Greece', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad25c'), 'TIME': 2000, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.28, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad25d'), 'TIME': 2001, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.24, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad25e'), 'TIME': 2002, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.25, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad25f'), 'TIME': 2003, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.28, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad260'), 'TIME': 2004, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.25, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad261'), 'TIME': 2005, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.23, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad262'), 'TIME': 2006, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.26, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad263'), 'TIME': 2007, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.34, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad264'), 'TIME': 2008, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.62, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad265'), 'TIME': 2009, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.02, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad266'), 'TIME': 2010, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.98, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad267'), 'TIME': 2011, 'GEO': 'Spain', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.82, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad268'), 'TIME': 2000, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.04, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad269'), 'TIME': 2001, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.95, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad26a'), 'TIME': 2002, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.9, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad26b'), 'TIME': 2003, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.92, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad26c'), 'TIME': 2004, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.8, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad26d'), 'TIME': 2005, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.67, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad26e'), 'TIME': 2006, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.61, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad26f'), 'TIME': 2007, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.62, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad270'), 'TIME': 2008, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.62, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad271'), 'TIME': 2009, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.9, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad272'), 'TIME': 2010, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.86, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad273'), 'TIME': 2011, 'GEO': 'France', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.68, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad274'), 'TIME': 2000, 'GEO': 'Italy', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.52, 'Flag and Footnotes': nan}
# ...
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e1'), 'TIME': 2001, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.42, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e2'), 'TIME': 2002, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.41, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e3'), 'TIME': 2003, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.35, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e4'), 'TIME': 2004, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.41, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e5'), 'TIME': 2005, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.47, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e6'), 'TIME': 2006, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.25, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e7'), 'TIME': 2007, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.91, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e8'), 'TIME': 2008, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.08, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2e9'), 'TIME': 2009, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.09, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2ea'), 'TIME': 2010, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.17, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2eb'), 'TIME': 2011, 'GEO': 'Poland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.94, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2ec'), 'TIME': 2000, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.42, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2ed'), 'TIME': 2001, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.39, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2ee'), 'TIME': 2002, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.33, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2ef'), 'TIME': 2003, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.38, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f0'), 'TIME': 2004, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.1, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f1'), 'TIME': 2005, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.21, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f2'), 'TIME': 2006, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.07, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f3'), 'TIME': 2007, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.1, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f4'), 'TIME': 2008, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.89, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f5'), 'TIME': 2009, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.79, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f6'), 'TIME': 2010, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.62, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f7'), 'TIME': 2011, 'GEO': 'Portugal', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.27, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f8'), 'TIME': 2000, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 2.88, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2f9'), 'TIME': 2001, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.25, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2fa'), 'TIME': 2002, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.51, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2fb'), 'TIME': 2003, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.45, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2fc'), 'TIME': 2004, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.28, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2fd'), 'TIME': 2005, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.48, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2fe'), 'TIME': 2006, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': 'u'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad2ff'), 'TIME': 2007, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.25, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad300'), 'TIME': 2008, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': 'u'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad301'), 'TIME': 2009, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.24, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad302'), 'TIME': 2010, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.53, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad303'), 'TIME': 2011, 'GEO': 'Romania', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.07, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad304'), 'TIME': 2000, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': nan, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad305'), 'TIME': 2001, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.86, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad306'), 'TIME': 2002, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.76, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad307'), 'TIME': 2003, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.8, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad308'), 'TIME': 2004, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.74, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad309'), 'TIME': 2005, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.73, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad30a'), 'TIME': 2006, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.72, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad30b'), 'TIME': 2007, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.15, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad30c'), 'TIME': 2008, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.2, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad30d'), 'TIME': 2009, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.69, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad30e'), 'TIME': 2010, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.68, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad30f'), 'TIME': 2011, 'GEO': 'Slovenia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.68, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad310'), 'TIME': 2000, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.92, 'Flag and Footnotes': 'i'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad311'), 'TIME': 2001, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.99, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad312'), 'TIME': 2002, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.31, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad313'), 'TIME': 2003, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.3, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad314'), 'TIME': 2004, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.19, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad315'), 'TIME': 2005, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.85, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad316'), 'TIME': 2006, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.8, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad317'), 'TIME': 2007, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.62, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad318'), 'TIME': 2008, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 3.61, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad319'), 'TIME': 2009, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.09, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad31a'), 'TIME': 2010, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.22, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad31b'), 'TIME': 2011, 'GEO': 'Slovakia', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 4.06, 'Flag and Footnotes': 'd'}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad31c'), 'TIME': 2000, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.89, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad31d'), 'TIME': 2001, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.06, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad31e'), 'TIME': 2002, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.22, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad31f'), 'TIME': 2003, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.43, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad320'), 'TIME': 2004, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.42, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad321'), 'TIME': 2005, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.3, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad322'), 'TIME': 2006, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.18, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad323'), 'TIME': 2007, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 5.9, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad324'), 'TIME': 2008, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.1, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad325'), 'TIME': 2009, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.81, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad326'), 'TIME': 2010, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.85, 'Flag and Footnotes': nan}
# {'_id': ObjectId('5dc99c5b2bbaa96d713ad327'), 'TIME': 2011, 'GEO': 'Finland', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'Value': 6.76, 'Flag and Footnotes': nan}

# %% [markdown]
# If we just want to know how many documents match a query we can perform a count() operation instead of a full query. We can get a count of all of the documents in a collection:

# %%
collection.count()

# %% [markdown]
# ### Basic queries

# %% [markdown]
# Querying in pymongo uses .find()

# %%
collection.find({"TIME":2009}).count()

# %%
collection.find({"GEO":"Spain"}).count()

# %% [markdown]
# Observe that it finds exact matches (including type)

# %%
collection.find({"TIME":"2009"}).count()

# %%
collection.find({"GEO":"SPAIN"}).count()

# %% [markdown]
# Operations include *gt* (greater than), *gte* (greater than equal), *lt* (lesser than), *lte* (lesser than equal), *ne* (not equal), *nin* (not in a list), *regex* (regular expression), *exists*, *not*, *or*, *and*, etc. Let us see some examples:

# %%
collection.find({"TIME":{"$gte":2009}}).count()

# %%
substring = r'Euro'
reg = substring
[print (i["GEO"]) for i in collection.find({"GEO":{"$regex":reg}})]

# %%
for item in collection.find({"GEO":{"$regex":reg}}):
    print (item['GEO'])

# %% [markdown]
# ### Update

# %% [markdown]
# In this section, several methods for updating and deleting documents are reveiwed:
#
# + Update. This method finds the documents defined by query and **replaces** it by the new document.

# %%
import numpy as np
doc = {'Flag and Footnotes': np.nan,
  'GEO': 'Andorra',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': np.nan}
collection.insert_one(doc)

# %%
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)

# %%
newdoc = {'Flag and Footnotes': np.nan,
  'GEO': 'Andorra',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': 10}
collection.replace_one({'GEO':"Andorra"},newdoc)

for doc in collection.find({'GEO':"Andorra"}):
    print (doc)

# %% [markdown]
# If we don't want to write again all the document and just put the field that we want to change then we have to use update_one and adding a sub-command.  Let us check some of them:

# %% [markdown]
# + Sub-command **Set**:
#
# This statement updates in the document in collection where field matches value1 by replacing the value of the field field1 with value2. This operator will add the specified field or fields if they do not exist in this document or replace the existing value of the specified field(s) if they already exist.
#
# An upsert eliminates the need to perform a separate database call to check for the existence of a record before performing either an update or an insert operation. Typically update operations update existing documents, but in MongoDB, the update_one() operation can accept an upsert option as an argument. Upserts are a hybrid operation that use the query argument to determine the write operation:
#
# If the query matches an existing document(s), the upsert performs an update.
# If the query matches no document in the collection, the upsert inserts a single document.

# %%
collection.update_one({'GEO':"Andorra"},{"$set":{"Value":12}})

# %%
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)

# %% [markdown]
# By default, if the filter doesn't return any document, nothing is inserted to database. If you want to insert it, then set the upsert flag to `True`

# %%
collection.update_one({'GEO':"Monaco"},{"$set":{"Value":12}},upsert = True)
for doc in collection.find({'GEO':"Monaco"}):
    print (doc)

# %% [markdown]
# + Sub-commnad **Unset**:
#
# The unset operator deletes a particular field. If documents match the initial query but do not have the field specified in the unset operation, there the statement has no effect on the document.

# %%
collection.update_one({'GEO':"Andorra"},{"$unset":{"Flag and Footnotes":""}})

# %%
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)

# %% [markdown]
# ### Delete operations

# %% [markdown]
# We can remove elements by simply:

# %%
collection.delete_one({"GEO":"Andorra"})

# %%
for doc in collection.find({"GEO":"Andorra"}):
    print (doc)

# %% [markdown]
# And remove a collection by:

# %%
dbCC.drop_collection("edu")

# %% [markdown]
# Check the collections:
#
# https://mlab.com/databases/cloudcomputing
#
# And close the connection to the database by:

# %%
# connCC.close()
client.close()

# %% [markdown]
# # Connecting to a local database
#
# First of all let us configure the MongoDB system.
#
# + Download mongoDB.
# + Create data directory:
#         mkdir -p /data/db
# + Check that the server works
#         mongod --nojournal &
# + Check the connection to the server:
#         in another terminal write `mongo`, check that it does not raise any error and exit the console.
# + Close the mongo daemon (mongod).
#         You may have to kill mongod with
#         killall mongod
#         and remove the lock on the daemon,
#         rm /data/db/mongod.lock.
# + Let us configure a little the data base by configuring the path of the data storage and log files. Create a [mongo.conf](./mongo.conf) file such as the one provided  and start the server using the following command:
#
#         mongod --config=./mongo.conf --nojournal &
# + Bonus: we can check the database status using  http://127.0.0.1:28017/
# + Install pymongo
#         pip install pymongo

# %%
import pymongo

# Connection to Mongo DB
try:
    connlocal=pymongo.MongoClient()
    print ("Connected successfully!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
connlocal

# %%
import pandas as pd

dblocal = connlocal['cloudcomputing']
print (connlocal.database_names())
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
collection = dblocal.edu
collection.insert_many(df.to_dict("records"))
print (dblocal.collection_names())
print (collection.find_one({'GEO':"Spain"}))

# %%
print (connlocal.database_names())
dblocal.drop_collection("edu")
#empty databases are not shown
print (connlocal.database_names())
connlocal.drop_database("cloudcomputing")
print (connlocal.database_names())
connlocal.close()
